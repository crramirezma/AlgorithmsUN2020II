# %% [markdown]
# ## Modification to plot a square in the complex palne with center in (z_c_r, z_c_i) and of size zw x zh
#
# Modfied from Fractals with Python - The Newton Set https://blog.anvetsu.com/posts/fractals-newton-python-matplotlib-numpy/
# from the Fractals with Python series https://blog.anvetsu.com/tags/fractal/
#
# German Hernandez
#
# ![picture](https://raw.githubusercontent.com/gjhernandezp/algorithms/master/Z3_1centermap.png)

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def f(z):
    return z ** 2 -1

def df(z):
    return 2 * z

def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 1
    r2 = -1

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2-1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %%
x = np.linspace(-5.0,5.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x^2-1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
print("zoom out")
display1(zoom=1)
display1(zoom=2)
display1(zoom=3)
display1(zoom=4)
display1(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
display1(zoom=1)
display1(zoom=1/2)
display1(zoom=1/3)
display1(zoom=1/4)
display1(zoom=1/5)
display1(zoom=1/10)
display1(zoom=1/100)
display1(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ## Newton iterates form z=10.0 + 0.0j

# %%
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=-10.0 + 0.0j

# %%
z=-10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 + 10.0j

# %%
z=-0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 - 10.0j

# %%
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ## Newton iterates form z=0.0 + 0.0j

# %%
z=-0.0 + 0.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-25b2b2c676bf> in <module>()
#       4 for k in range(200):
#       5   dz = df(z)
# ----> 6   z = z - f(z) / dz # Newton iteration
#       7   r.append(np.real(z))
#       8   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# #Solución laboratorio #6

# %% [markdown]
# ## Creando las funciones para los metodos de poh Shen loh y el metodo de Newton para resolver ecuaciones cuadraticas

# %% [markdown]
# ### Metodo de Newton

# %%
#Usamos la formula de la cuadratica

#primero definimos la funcion de cuadratica explicita sin evaluacion de errores
def cuad(a,b,c):
  r=(b**2)-(4*a*c)
  #validando si tiene valores complejos
  #el valor absoluto nos devuelve la parte positiva, la parte negativa se va con el "i"
  if r<0:
    x_0=str(-b/(2*a))+"+"+str(math.sqrt(abs(r))/(2*a))+"i"
    x_1=str(-b/(2*a))+"-"+str(math.sqrt(abs(r))/(2*a))+"i"
  else: 
    x_0=(-b+math.sqrt((b**2)-(4*a*c)))/(2*a)
    x_1=(-b-math.sqrt((b**2)-(4*a*c)))/(2*a)
  return (x_0,x_1)

#luego se implementa la evaluación de errores(ejemplo a=0->division por cero), entre otros
def Newton(a,b,c):
  try:
    if a!=0:
      r=cuad(a,b,c)
      print("la primera raiz es: ",r[0],"\nY la segunda es: ",r[1])
    else:#dado que a=0, la ecuacion seria de primer grado
      if b!=0:
        print("La raiz de la función es: "+c/b)
      else:
        if c!=0:
          print("la función no tiene solución")
        else:
          print("La función tiene infinitas soluciones")
  except:
    print("Error con los datos introducidos")

# %% [markdown]
# ### Metodo de Poh Shen Loh

# %%
#recalcar que en el metodo de poh, el coeficiente del termino elevado al cuadrado, debe ser 1

#primero definimos la funcion de cuadratica explicita sin evaluacion de errores
def cuad_shen(b,c):
  
  r1=(b**2/4)-c

  #validando si tiene valores complejos
  #el valor absoluto nos devuelve la parte positiva, la parte negativa se va con el "i"
  if r1<0:
    x_0=str(-b/2)+"+"+str(math.sqrt(abs(r1)))+"i"
    x_1=str(-b/2)+"-"+str(math.sqrt(abs(r1)))+"i"
  else:
    x_0=((-(b/2))+math.sqrt(r1))
    x_1=(-(b/2)-math.sqrt(r1))
  return (x_0,x_1)

#el metodo de poh es mas ligero en errores que la versión de Newton
#esto gracias a que no existe la posibilidad de una division por 0
def poh(b,c):
  r=cuad_shen(b,c)
  print("la primera raiz es: ",r[0],"\nY la segunda es: ",r[1])

# %% [markdown]
# * ##  x²

# %%
def f(z):
    return z ** 2 

def df(z):
    return 2 * z

def newton_set1_0(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 0

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol =5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                
                else:   
                   pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
               
    return pixels

def display1_0(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1_0(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2-1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# ### Plot de la función

# %%
x = np.linspace(-5.0,5.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x^2-1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# ###  Solucion de la cuadratica por el metodo de Newton y el metodo de Poh Shen Loh

# %% [markdown]
# Primero identificamos los coeficientes del polinomio de la forma: ax²+bx+c
# En este caso, para la funcion x^2 quedaria asi:
# * a=1
# * b=0
# * c=0
#
# Tomando de la forma: (1)x²+(0)x+0

# %%
#solucion con los puntos dados de a,b y c usando el Metodo de Newton diseñado anteriormente
Newton(1,0,0)
# Out:
# la primera raiz es:  0.0
# Y la segunda es:  0.0

# %%
#solucion con los puntos dados de a,b y c usando el Metodo de Poh Shen loh diseñado anteriormente
poh(0,0)
# Out:
# la primera raiz es:  0.0
# Y la segunda es:  -0.0

# %% [markdown]
# ###Fractal de Newton para la funcion z^2

# %%
print("zoom out")
display1_0(zoom=1)
display1_0(zoom=2)
display1_0(zoom=3)
display1_0(zoom=4)
display1_0(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
display1_0(zoom=1)
display1_0(zoom=1/2)
display1_0(zoom=1/3)
display1_0(zoom=1/4)
display1_0(zoom=1/5)
display1_0(zoom=1/10)
display1_0(zoom=1/100)
display1_0(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ### Newton Iterates Forms

# %% [markdown]
# #### Newton iterates form z=10.0 + 0.0j

# %%
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# Conclusiones:

# %% [markdown]
# #### Newton iterates form z=-10.0 + 0.0j

# %%
z=-10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 + 10.0j

# %%
z=0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 - 10.0j

# %%
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 + 0.0j

# %%
z=-0.0 + 0.0j
r=[]
i=[]
h = 1e-7
for k in range(200):
  dz = df(z)

  #la funcion tiene error porque se intenta dividir por cero, por lo que tuve que ingeniarme una manera de calcularlo sin alterar el resultado
  if dz==0:
    #le sumo a la variable problema, el minimo h, un numero muy cercano a 0
    #como se esta evaluando si es 0, signo positivo, la suma no alterara el signo
    dz=dz+h
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# * ##  (x-1)²

# %%
def f(z):
    return (z-1)**2

def df(z):
    return 2*(z-1)

def newton_set2(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 1
    

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                
                else:   
                   pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
               
    return pixels

def display2(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set2(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2-1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# ### Plot de la función

# %%
x = np.linspace(-4.0,6.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=(x-1)^2')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# ###  Solucion de la cuadratica por el metodo de Newton y el metodo de Poh Shen Loh

# %% [markdown]
# Primero identificamos los coeficientes del polinomio de la forma: ax²+bx+c
# En este caso, para la funcion (x-1)^2 quedaria asi:
# * a=1
# * b=-2
# * c=1
#
# Tomado de la forma: (1)x²+(-2)x+1(expandiendo la función)

# %%
#solucion con los puntos dados de a,b y c usando el Metodo de Newton diseñado anteriormente
Newton(1,-2,1)
# Out:
# la primera raiz es:  1.0
# Y la segunda es:  1.0

# %%
#solucion con los puntos dados de a,b y c usando el Metodo de Poh Shen loh diseñado anteriormente
poh(-2,1)
# Out:
# la primera raiz es:  1.0
# Y la segunda es:  1.0

# %% [markdown]
# ### Fractales de newton

# %%
print("zoom out")
display2(zoom=1)
display2(zoom=2)
display2(zoom=3)
display2(zoom=4)
display2(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
display2(zoom=1)
display2(zoom=1/2)
display2(zoom=1/3)
display2(zoom=1/4)
display2(zoom=1/5)
display2(zoom=1/10)
display2(zoom=1/100)
display2(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ### Graficando la forma iterada de Newton

# %% [markdown]
# #### Newton iterates form z=10.0 + 0.0j

# %%
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=-10.0 + 0.0j

# %%
z=-10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 + 10.0j

# %%
z=0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 - 10.0j

# %%
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 + 0.0j

# %%
z=-0.0 + 0.0j
r=[]
i=[]
h = 1e-7
for k in range(200):
  dz = df(z)

  #la funcion tiene error porque se intenta dividir por cero, por lo que tuve que ingeniarme una manera de calcularlo sin alterar el resultado
  if dz==0:
    #le sumo a la variable problema, el minimo h, un numero muy cercano a 0
    #como se esta evaluando si es 0, signo positivo, la suma no alterara el signo
    dz=dz+h
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# * ##  x² -1

# %%
def f(z):
    return z ** 2 -1

def df(z):
    return 2 * (z)

def newton_set3(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = 1
    r2 = -1

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display3(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set3(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2-1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# ### Plot de la funcion

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=(x^2)-1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# ###  Solucion de la cuadratica por el metodo de Newton y el metodo de Poh Shen Loh

# %% [markdown]
# Primero identificamos los coeficientes del polinomio de la forma: ax²+bx+c
# En este caso, para la funcion x² -1 quedaria asi:
# * a=1
# * b=0
# * c=-1
#
# Tomando de la forma: (1)x²+(0)x-1

# %%
#solucion con los puntos dados de a,b y c usando el Metodo de Newton diseñado anteriormente
Newton(1,0,-1)
# Out:
# la primera raiz es:  1.0
# Y la segunda es:  -1.0

# %%
#solucion con los puntos dados de a,b y c usando el Metodo de Poh Shen loh diseñado anteriormente
poh(0,-1)
# Out:
# la primera raiz es:  1.0
# Y la segunda es:  -1.0

# %% [markdown]
# ### Fractales de Newton

# %%
print("zoom out")
display3(zoom=1)
display3(zoom=2)
display3(zoom=3)
display3(zoom=4)
display3(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
display3(zoom=1)
display3(zoom=1/2)
display3(zoom=1/3)
display3(zoom=1/4)
display3(zoom=1/5)
display3(zoom=1/10)
display3(zoom=1/100)
display3(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ### Graficando la forma iterada de Newton

# %% [markdown]
# #### Newton iterates form z=10.0 + 0.0j

# %%
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=-10.0 + 0.0j

# %%
z=-10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 + 10.0j

# %%
z=0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 - 10.0j

# %%
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 + 0.0j

# %%
z=-0.0 + 0.0j
r=[]
i=[]
h = 1e-7
for k in range(200):
  dz = df(z)

  #la funcion tiene error porque se intenta dividir por cero, por lo que tuve que ingeniarme una manera de calcularlo sin alterar el resultado
  if dz==0:
    #le sumo a la variable problema, el minimo h, un numero muy cercano a 0
    #como se esta evaluando si es 0, signo positivo, la suma no alterara el signo
    dz=dz+h
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# * ##  (x²) +1

# %%
def f(z):
    return z ** 2 +1

def df(z):
    return 2 * (z)

def newton_set4(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = complex(0,1)
    r2 = complex(0,-1)

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
               
    return pixels

def display4(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set4(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal f(x)=Z^2-1')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# ###Plot de la funcion

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=(x^2)-1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# ###  Solucion de la cuadratica por el metodo de Newton y el metodo de Poh Shen Loh

# %% [markdown]
# Primero identificamos los coeficientes del polinomio de la forma: ax²+bx+c
# En este caso, para la funcion x²+1 quedaria asi:
# * a=1
# * b=0
# * c=1
#
# Tomando de la forma: (1)x²+(0)x+1

# %%
#solucion con los puntos dados de a,b y c usando el Metodo de Newton diseñado anteriormente
Newton(1,0,1)
# Out:
# la primera raiz es:  0.0+1.0i
# Y la segunda es:  0.0-1.0i

# %%
#solucion con los puntos dados de a,b y c usando el Metodo de Poh Shen loh diseñado anteriormente
poh(0,1)
# Out:
# la primera raiz es:  0.0+1.0i
# Y la segunda es:  0.0-1.0i

# %% [markdown]
# ### Fractales de Newton

# %%
print("zoom out")
display4(zoom=1)
display4(zoom=2)
display4(zoom=3)
display4(zoom=4)
display4(zoom=5)
# Out:
# zoom out
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %%
print("zoom in")
display4(zoom=1)
display4(zoom=1/2)
display4(zoom=1/3)
display4(zoom=1/4)
display4(zoom=1/5)
display4(zoom=1/10)
display4(zoom=1/100)
display4(zoom=1/1000)
# Out:
# zoom in
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Z region from ( -0.05 , -0.05 ) to ( 0.05 , 0.05 )
# Z region from ( -0.005 , -0.005 ) to ( 0.005 , 0.005 )
# Z region from ( -0.0005 , -0.0005 ) to ( 0.0005 , 0.0005 )

# %% [markdown]
# ### Graficando la forma iterada de Newton

# %% [markdown]
# #### Newton iterates form z=10.0 + 0.0j

# %%
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imagnary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=-10.0 + 0.0j

# %%
z=-10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=-10.0 + 0.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 + 10.0j

# %%
z=0.0 + 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 + 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 - 10.0j

# %%
z=-0.0 - 10.0j
r=[]
i=[]
for k in range(200):
  dz = df(z)
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form z=0.0 - 10.0j')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# #### Newton iterates form z=0.0 + 0.0j

# %%
z=-0.0 + 0.0j
r=[]
i=[]
h = 1e-7
for k in range(200):
  dz = df(z)

  #la funcion tiene error porque se intenta dividir por cero, por lo que tuve que ingeniarme una manera de calcularlo sin alterar el resultado
  if dz==0:
    #le sumo a la variable problema, el minimo h, un numero muy cercano a 0
    #como se esta evaluando si es 0, signo positivo, la suma no alterara el signo
    dz=dz+h
  z = z - f(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()
