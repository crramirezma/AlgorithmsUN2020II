# %% [markdown]
# ![pancakespilesPythonlists.png](http://ungrid.unal.edu.co/gjhernandezp/algorithms/pancakes/pancakespilesPythonlistsonespatula.png)

# %%
import pydot
from collections import defaultdict 
from IPython.display import Image, display

# %%
def lstr(p):
        return ''.join([str(elem)  for elem in p])

# %%
def ModifiedBFS(s): 

        # Create diction de datosaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            node = pydot.Node(lstr(s))
            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                    node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [1,3,2]
ModifiedBFS(p)

# %%
def ModifiedBFSPreSols(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))

            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if (d != sorted(d)):
                     node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                    print(i)
                  
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [1,3,2]
ModifiedBFSPreSols(p)
# Out:
# 0

# %%
def ModifiedBFSPreSolsLevel(s,L):  

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append([s,0]) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            e = queue.pop(0)
            s = e[0]
            l = e[1] 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))

            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)) and (l < L):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                     node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append([d,l+1]) 
                  visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [5,2,3,4,1]
ModifiedBFSPreSolsLevel(p,3)

# %%
ModifiedBFSPreSolsLevel(p,5)

# %% [markdown]
# ## References
#
# - Breadth First Search or BFS for a Graph https://www.geeksforgeeks.org/breadth-first-search-or-bfs-for-a-graph/
#
# - Graph visualization using Python https://www.youtube.com/watch?v=SpDI6-FvtJY
#
# - nikhilkumarsingh
# /
# PyDot-Examples https://github.com/nikhilkumarsingh/PyDot-Examples/blob/master/Directory_Structure_Plotter.ipynb
#
# - pydot https://pypi.org/project/pydot/
#
# - Graphviz https://www.graphviz.org/
#
# - NetworkX https://networkx.github.io/

# %% [markdown]
# # Solución

# %% [markdown]
# ## Codigo de 8 horas

# %%
def Pn(s):  
        l=0
        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append([s,0]) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            e = queue.pop(0)
            s = e[0]
            l = e[1] 
            graph[lstr(s)]=[]

            
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            
            for i in range(len(s)-1):
              d = s[i+1::-1] + s[i+2:]  
              if (d != s) and not(lstr(d) in visited.keys()):
                
                if (d != sorted(d)):
                    
                    visited[lstr(d)] = True 
                
                
               
                graph[lstr(s)].append(lstr(d))
                queue.append([d,l+1]) 
                
                
                
        # Dsplay the pydot graph G
        print(l)

# %%
import random
#Funcion que retorna una lista de numeros en un rango de 0 a i, pero no de forma ordenada
def lista_desort(i):
  lista=[]
  while len(lista)<i:
    k=random.randint(1,i)
    #si el valor no esta en la lista, lo agrega
    if k not in lista:
      lista.append(k)
  return lista

# %%
i=5
#Dado que segun la teoria, para un n>=14, el programa tomaria mucho tiempo
#la funcion de "lista_desort" no afectara en lo mas minimo al tiempo de ejecución
while True:
  p=lista_desort(i)
  #Valores de retorno
    #n: Cantidad de datos
    #p: Lista generada aleatoriamente
    #Pn: cantidad de flips de la espatula
  print("n:",i,", p:",p,end=", Pn:")
  Pn(p)
  i=i+1
# Out:
# n: 5 , p: [1, 2, 4, 3, 5], Pn:5
# n: 6 , p: [3, 1, 6, 4, 2, 5], Pn:7
# n: 7 , p: [5, 4, 6, 1, 2, 3, 7], Pn:8
# n: 8 , p: [1, 3, 6, 5, 2, 8, 7, 4], Pn:9
# n: 9 , p: [5, 1, 3, 2, 7, 4, 9, 8, 6], Pn:10
# n: 10 , p: [4, 1, 9, 6, 8, 10, 2, 5, 7, 3], Pn:12
# n: 11 , p: [9, 2, 11, 10, 7, 3, 6, 5, 4, 1, 8], Pn:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-6bb9f5c95d39> in <module>()
#       9     #Pn: cantidad de flips de la espatula
#      10   print("n:",i,", p:",p,end=", Pn:")
# ---> 11   Pn(p)
#      12   i=i+1
#
# <ipython-input-40-695506e1e0f2> in Pn(s)
#      16
#      17             # Dequeue a vertex from queue
# ---> 18             e = queue.pop(0)
#      19             s = e[0]
#      20             l = e[1]
#
# KeyboardInterrupt:

# %% [markdown]
# ### Proceso atravez de las horas

# %% [markdown]
# Imagen del inicio del proceso a las 6:40 am
#
# <img src="https://raw.githubusercontent.com/crramirezma/AlgorithmsUN2020II/master/Pancakes/imagenes/Inicio.png">

# %% [markdown]
# Avance a la 1:32 pm
#
# <img src="https://raw.githubusercontent.com/crramirezma/AlgorithmsUN2020II/master/Pancakes/imagenes/1_33.PNG">

# %% [markdown]
# Avance a las 4:24 pm
#
# <img src="https://raw.githubusercontent.com/crramirezma/AlgorithmsUN2020II/master/Pancakes/imagenes/4_24.PNG">

# %% [markdown]
# Finalizacion forzada a las 4:30 pm
#
# <img src="https://raw.githubusercontent.com/crramirezma/AlgorithmsUN2020II/master/Pancakes/imagenes/4_30.PNG">

# %% [markdown]
# ## Pancakes con dos espatulas

# %%
def dosEspatulas(s,L):  

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append([s,0]) 
        
        visited[lstr(s)] = True
  
        while queue: 
            
            # Dequeue a vertex from queue 
            e = queue.pop(0)
            s = e[0]
            l = e[1] 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
              for j in range(i,len(s)):
                d = s[:j]+s[j:i+2][::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))

            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)) and (l < L):
              for i in range(len(s)-1):
                for j in range(i+1):
                  
                  #agrega a la lista los valores antes de la j(espatula superior)
                  #luego toma los valores en el rango (j,i+2) y los gira
                  #por ultimo agrega los datos que le faltan, los que estan debajo de i(espatula superior)
                  d = s[:j]+s[j:i+2][::-1] + s[i+2:]
                  if (d != s) and not(lstr(d) in visited.keys()):
                  
                    if (d != sorted(d)):
                      
                      node = pydot.Node(lstr(d))
                    else:
                      
                      node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                    
                    G.add_node(node)
                    edge = pydot.Edge(lstr(s),lstr(d))
                    G.add_edge(edge)
                    graph[lstr(s)].append(lstr(d))
                    queue.append([d,l+1]) 
                    visited[lstr(d)] = True 
                    
            
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p=[5,3,1,4,2]
dosEspatulas(p,5)
# Out:
# 2

# %% [markdown]
# **NOTA:** gracias al algoritmo que se ejecuto por mas de 8 horas, se me es imposible reefectuar todas las ejecuciones
